# %%
#Dobro
num = 42
print (num * 2)
# Out:
# 84

# %%
#Média 
n1 = 8
n2 = 6.5
n3 = 7
media = (n1+n2+n3)/3
print(media)
# Out:
# 7.166666666666667

# %%
#Trabalhando com INPUTS
nome = input('Digite seu nome')
print('Olá '+nome)
# Out:
# Digite seu nome Wallace
# Olá  Wallace

# %%
#Pede um número e multiplica por 1
#PARSE
num = input(' Digitar número!')
print(num*3)
# Out:
#  Digitar número!500
# 500500500

# %%
#Calcula Idade
AnoNascim = 2002
print(2023 - 2002)
# Out:
# 21
